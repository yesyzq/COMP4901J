# %%
import tensorflow as tf
import numpy as np
import math
import timeit
import matplotlib.pyplot as plt
import os
from scipy import misc

# %matplotlib inline

# %%
def get_data(dirname):
    img_names = os.listdir(dirname)
    img_names = [f for f in img_names if f.endswith(".jpeg")]
    X = np.ndarray((len(img_names),512 * 512), dtype='uint16')
    y = np.array(len(img_names), dtype='uint16')
    
    for num, img in enumerate(img_names):
        X[num,:] = misc.imread(dirname + "/" + img, mode='l')
        y[num] = int(img[0])
            
        num_testing = 5
        num_validation = 5
        num_training = len(img_names) - num_testing - num_validation
        # Subsample the data
        mask = range(num_training + num_testing, num_training + num_validation + num_testing)
        X_val = X[mask]
        y_val = y[mask]
        mask = range(num_training, num_training + num_testing)
        X_test = X[mask]
        y_test = y[mask]
        mask = range(num_training)
        X_train = X[mask]
        y_train = y[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    
    return X, y

get_data("images")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-714fb97d0a67> in <module>()
#      31     return X, y
#      32
# ---> 33 get_data("images")
#
# <ipython-input-4-714fb97d0a67> in get_data(dirname)
#       6
#       7     for num, img in enumerate(img_names):
# ----> 8         X[num,:] = misc.imread(img, mode='l')
#       9         y[num] = int(img[0])
#      10
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/scipy/misc/pilutil.py in imread(name, flatten, mode)
#     154     """
#     155
# --> 156     im = Image.open(name)
#     157     return fromimage(im, flatten=flatten, mode=mode)
#     158
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2475
#    2476     if filename:
# -> 2477         fp = builtins.open(filename, "rb")
#    2478         exclusive_fp = True
#    2479
#
# FileNotFoundError: [Errno 2] No such file or directory: '0_0.jpeg'

# %%
def run_model(session, predict, loss_val, Xd, yd,
              epochs=1, batch_size=64, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    correct_prediction = tf.equal(tf.argmax(predict,1), y)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # shuffle indicies
    train_indicies = np.arange(Xd.shape[0])
    np.random.shuffle(train_indicies)

    training_now = training is not None
    
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [mean_loss,correct_prediction,accuracy]
    if training_now:
        variables[-1] = training
    
    # counter 
    iter_cnt = 0
    for e in range(epochs):
        # keep track of losses and accuracy
        correct = 0
        losses = []
        # make sure we iterate over the dataset once
        for i in range(int(math.ceil(Xd.shape[0]/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%Xd.shape[0]
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            # create a feed dictionary for this batch
            feed_dict = {X: Xd[idx,:],
                         y: yd[idx],
                         is_training: training_now }
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step
            loss, corr, _ = session.run(variables,feed_dict=feed_dict)
            
            # aggregate performance stats
            losses.append(loss*actual_batch_size)
            correct += np.sum(corr)
            
            # print every now and then
            if training_now and (iter_cnt % print_every) == 0:
                print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"\
                      .format(iter_cnt,loss,np.sum(corr)/actual_batch_size))
            iter_cnt += 1
        total_correct = correct/Xd.shape[0]
        total_loss = np.sum(losses)/Xd.shape[0]
        print("Epoch {2}, Overall loss = {0:.3g} and accuracy of {1:.3g}"\
              .format(total_loss,total_correct,e+1))
        if plot_losses:
            plt.plot(losses)
            plt.grid(True)
            plt.title('Epoch {} Loss'.format(e+1))
            plt.xlabel('minibatch number')
            plt.ylabel('minibatch loss')
            plt.show()
    return total_loss,total_correct
# Out:
# Training
# Iteration 0: with minibatch training loss = 3.08 and accuracy of 0.078
# Iteration 100: with minibatch training loss = 1.87 and accuracy of 0.28
# Iteration 200: with minibatch training loss = 2.26 and accuracy of 0.19
# Iteration 300: with minibatch training loss = 1.53 and accuracy of 0.42
# Iteration 400: with minibatch training loss = 1.22 and accuracy of 0.56
# Iteration 500: with minibatch training loss = 1.49 and accuracy of 0.36
# Iteration 600: with minibatch training loss = 1.44 and accuracy of 0.47
# Iteration 700: with minibatch training loss = 1.37 and accuracy of 0.53
# Epoch 1, Overall loss = 1.49 and accuracy of 0.465
# Validation
# Epoch 1, Overall loss = 5.98 and accuracy of 0.338

# %%
# clear old variables
tf.reset_default_graph()

# define our input (e.g. the data that changes every batch)
# The first dim is None, and gets sets automatically based on batch size fed in
X = tf.placeholder(tf.float32, [None, 32, 32, 3])
y = tf.placeholder(tf.int64, [None])
is_training = tf.placeholder(tf.bool)

def my_model(X,y,is_training):
    Wconv1 = tf.get_variable("Wconv1", shape=[5, 5, 3, 32])
    bconv1 = tf.get_variable("bconv1", shape=[32])
    Wconv2 = tf.get_variable("Wconv2", shape=[5, 5, 32, 32])
    bconv2 = tf.get_variable("bconv2", shape=[32])
    Wconv3 = tf.get_variable("Wconv3", shape=[5, 5, 32, 64])
    bconv3 = tf.get_variable("bconv3", shape=[64])
    
    W1 = tf.get_variable("W1", shape=[1024, 64])
    b1 = tf.get_variable("b1", shape=[64])
    W2 = tf.get_variable("W2", shape=[64, 10])
    b2 = tf.get_variable("b2", shape=[10])

    a1 = tf.nn.conv2d(X, Wconv1, strides=[1,1,1,1], padding='SAME') + bconv1
    p1 = tf.layers.max_pooling2d(a1, 2, 2)
    bn1 = tf.contrib.layers.batch_norm(p1, center=True, scale=True,
                                    is_training=is_training) # disbale reuse, not specify scope
    h1 = tf.nn.relu(bn1)
    
    a2 = tf.nn.conv2d(h1, Wconv2, strides=[1,1,1,1], padding='SAME') + bconv2
    p2 = tf.layers.max_pooling2d(a2, 2, 2)
    bn2 = tf.contrib.layers.batch_norm(p2, center=True, scale=True,
                                    is_training=is_training)
    h2 = tf.nn.relu(bn2)
    
    
    a3 = tf.nn.conv2d(h2, Wconv3, strides=[1,1,1,1], padding='SAME') + bconv3
    p3 = tf.layers.max_pooling2d(a3, 2, 2)
    bn3 = tf.contrib.layers.batch_norm(p3, center=True, scale=True,
                                    is_training=is_training)
    h3 = tf.nn.relu(bn3)
    
    # affine layer
    h5_flat = tf.reshape(h3,[-1,1024])
    h6_flat = tf.matmul(h5_flat,W1) + b1
    h7_flat = tf.nn.relu(h6_flat)
    y_out = tf.matmul(h7_flat,W2) + b2

    return y_out

y_out = my_model(X,y,is_training)
mean_loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=y_out, labels=tf.squeeze(y)))
optimizer = tf.train.RMSPropOptimizer(0.01)

# batch normalization in tensorflow requires this extra dependency
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    train_step = optimizer.minimize(mean_loss)

# %%
# Feel free to play with this cell
# This default code creates a session
# and trains your model for 10 epochs
# then prints the validation set accuracy
with tf.Session() as sess:
    with tf.device("/gpu:0"): #"/cpu:0" or "/gpu:0" 
        sess.run(tf.global_variables_initializer())
        print('Training')
        run_model(sess,y_out,mean_loss,X_train,y_train,10,64,100,train_step,True)
        print('Validation')
        run_model(sess,y_out,mean_loss,X_val,y_val,1,64)
# Out:
# Training
# Iteration 0: with minibatch training loss = 2.82 and accuracy of 0.094
# Iteration 100: with minibatch training loss = 2.01 and accuracy of 0.38
# Iteration 200: with minibatch training loss = 1.61 and accuracy of 0.44
# Iteration 300: with minibatch training loss = 1.42 and accuracy of 0.45
# Iteration 400: with minibatch training loss = 1.35 and accuracy of 0.48
# Iteration 500: with minibatch training loss = 1.11 and accuracy of 0.61
# Iteration 600: with minibatch training loss = 1.14 and accuracy of 0.58
# Iteration 700: with minibatch training loss = 1.31 and accuracy of 0.58
# Epoch 1, Overall loss = 1.46 and accuracy of 0.473
# Iteration 800: with minibatch training loss = 1.39 and accuracy of 0.55
# Iteration 900: with minibatch training loss = 0.996 and accuracy of 0.67
# Iteration 1000: with minibatch training loss = 1.08 and accuracy of 0.61
# Iteration 1100: with minibatch training loss = 0.654 and accuracy of 0.78
# Iteration 1200: with minibatch training loss = 0.764 and accuracy of 0.73
# Iteration 1300: with minibatch training loss = 0.88 and accuracy of 0.7
# Iteration 1400: with minibatch training loss = 1.02 and accuracy of 0.66
# Iteration 1500: with minibatch training loss = 0.684 and accuracy of 0.75
# Epoch 2, Overall loss = 0.981 and accuracy of 0.659
# Iteration 1600: with minibatch training loss = 0.855 and accuracy of 0.72
# Iteration 1700: with minibatch training loss = 0.992 and accuracy of 0.69
# Iteration 1800: with minibatch training loss = 0.94 and accuracy of 0.67
# Iteration 1900: with minibatch training loss = 0.737 and accuracy of 0.73
# Iteration 2000: with minibatch training loss = 0.851 and accuracy of 0.72
# Iteration 2100: with minibatch training loss = 0.642 and accuracy of 0.81
# Iteration 2200: with minibatch training loss = 0.846 and accuracy of 0.69
# Epoch 3, Overall loss = 0.82 and accuracy of 0.719
# Iteration 2300: with minibatch training loss = 0.713 and accuracy of 0.78
# Iteration 2400: with minibatch training loss = 0.698 and accuracy of 0.78
# Iteration 2500: with minibatch training loss = 0.753 and accuracy of 0.73
# Iteration 2600: with minibatch training loss = 0.865 and accuracy of 0.67
# Iteration 2700: with minibatch training loss = 0.709 and accuracy of 0.75
# Iteration 2800: with minibatch training loss = 0.621 and accuracy of 0.8
# Iteration 2900: with minibatch training loss = 0.413 and accuracy of 0.86
# Iteration 3000: with minibatch training loss = 0.581 and accuracy of 0.8
# Epoch 4, Overall loss = 0.721 and accuracy of 0.754
# Iteration 3100: with minibatch training loss = 0.794 and accuracy of 0.72
# Iteration 3200: with minibatch training loss = 0.905 and accuracy of 0.7
# Iteration 3300: with minibatch training loss = 0.482 and accuracy of 0.83
# Iteration 3400: with minibatch training loss = 0.627 and accuracy of 0.78
# Iteration 3500: with minibatch training loss = 0.532 and accuracy of 0.86
# Iteration 3600: with minibatch training loss = 0.635 and accuracy of 0.81
# Iteration 3700: with minibatch training loss = 0.577 and accuracy of 0.8
# Iteration 3800: with minibatch training loss = 0.607 and accuracy of 0.78
# Epoch 5, Overall loss = 0.652 and accuracy of 0.779
# Iteration 3900: with minibatch training loss = 0.741 and accuracy of 0.73
# Iteration 4000: with minibatch training loss = 0.736 and accuracy of 0.73
# Iteration 4100: with minibatch training loss = 0.762 and accuracy of 0.77
# Iteration 4200: with minibatch training loss = 1.12 and accuracy of 0.66
# Iteration 4300: with minibatch training loss = 0.772 and accuracy of 0.72
# Iteration 4400: with minibatch training loss = 0.595 and accuracy of 0.75
# Iteration 4500: with minibatch training loss = 0.592 and accuracy of 0.81
# Epoch 6, Overall loss = 0.599 and accuracy of 0.796
# Iteration 4600: with minibatch training loss = 0.324 and accuracy of 0.91
# Iteration 4700: with minibatch training loss = 0.606 and accuracy of 0.81
# Iteration 4800: with minibatch training loss = 0.556 and accuracy of 0.81
# Iteration 4900: with minibatch training loss = 0.378 and accuracy of 0.84
# Iteration 5000: with minibatch training loss = 0.464 and accuracy of 0.86
# Iteration 5100: with minibatch training loss = 0.415 and accuracy of 0.89
# Iteration 5200: with minibatch training loss = 0.333 and accuracy of 0.88
# Iteration 5300: with minibatch training loss = 0.699 and accuracy of 0.75
# Epoch 7, Overall loss = 0.557 and accuracy of 0.812
# Iteration 5400: with minibatch training loss = 0.431 and accuracy of 0.88
# Iteration 5500: with minibatch training loss = 0.525 and accuracy of 0.83
# Iteration 5600: with minibatch training loss = 0.709 and accuracy of 0.81
# Iteration 5700: with minibatch training loss = 0.982 and accuracy of 0.77
# Iteration 5800: with minibatch training loss = 0.854 and accuracy of 0.81
# Iteration 5900: with minibatch training loss = 0.663 and accuracy of 0.75
# Iteration 6000: with minibatch training loss = 0.349 and accuracy of 0.88
# Iteration 6100: with minibatch training loss = 0.58 and accuracy of 0.78
# Epoch 8, Overall loss = 0.533 and accuracy of 0.821
# Iteration 6200: with minibatch training loss = 0.582 and accuracy of 0.78
# Iteration 6300: with minibatch training loss = 0.463 and accuracy of 0.86
# Iteration 6400: with minibatch training loss = 0.319 and accuracy of 0.88
# Iteration 6500: with minibatch training loss = 0.368 and accuracy of 0.89
# Iteration 6600: with minibatch training loss = 0.593 and accuracy of 0.81
# Iteration 6700: with minibatch training loss = 0.554 and accuracy of 0.83
# Iteration 6800: with minibatch training loss = 0.78 and accuracy of 0.77
# Epoch 9, Overall loss = 0.506 and accuracy of 0.83
# Iteration 6900: with minibatch training loss = 0.379 and accuracy of 0.84
# Iteration 7000: with minibatch training loss = 0.396 and accuracy of 0.81
# Iteration 7100: with minibatch training loss = 0.401 and accuracy of 0.86
# Iteration 7200: with minibatch training loss = 0.379 and accuracy of 0.81
# Iteration 7300: with minibatch training loss = 0.404 and accuracy of 0.88
# Iteration 7400: with minibatch training loss = 0.737 and accuracy of 0.78
# Iteration 7500: with minibatch training loss = 0.301 and accuracy of 0.84
# Iteration 7600: with minibatch training loss = 0.578 and accuracy of 0.83
# Epoch 10, Overall loss = 0.488 and accuracy of 0.836
# Validation
# Epoch 1, Overall loss = 1.49 and accuracy of 0.706
